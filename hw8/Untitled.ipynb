# %%
content = [{'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
   {'alias': 'cafes', 'title': 'Cafes'},
   {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
  'coordinates': {'latitude': 40.810041, 'longitude': -73.958693},
  'display_phone': '(646) 820-7735',
  'distance': 424.39636460686995,
  'id': 'flat-top-new-york',
  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IO4ffkg3h5DGnWE_JvTm8g/o.jpg',
  'is_closed': False,
  'location': {'address1': '1241 Amsterdam Ave',
   'address2': '',
   'address3': '',
   'city': 'New York',
   'country': 'US',
   'display_address': ['1241 Amsterdam Ave', 'New York, NY 10027'],
   'state': 'NY',
   'zip_code': '10027'},
  'name': 'Flat Top',
  'phone': '+16468207735',
  'price': '$$',
  'rating': 4.0,
  'review_count': 340,
  'transactions': ['restaurant_reservation'],
  'url': 'https://www.yelp.com/biz/flat-top-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
   {'alias': 'gluten_free', 'title': 'Gluten-Free'},
   {'alias': 'newamerican', 'title': 'American (New)'}],
  'coordinates': {'latitude': 40.8084415644407,
   'longitude': -73.9598026871681},
  'display_phone': '(212) 932-0600',
  'distance': 240.73280686001996,
  'id': 'friedmans-new-york-62',
  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pfIqvvNLdhR9kE1fjqylvg/o.jpg',
  'is_closed': False,
  'location': {'address1': '1187 Amsterdam Ave',
   'address2': '',
   'address3': '',
   'city': 'New York',
   'country': 'US',
   'display_address': ['1187 Amsterdam Ave', 'New York, NY 10027'],
   'state': 'NY',
   'zip_code': '10027'},
  'name': "Friedman's",
  'phone': '+12129320600',
  'price': '$$',
  'rating': 4.0,
  'review_count': 226,
  'transactions': [],
  'url': 'https://www.yelp.com/biz/friedmans-new-york-62?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'}],
  'coordinates': {'latitude': 40.80522, 'longitude': -73.96639},
  'display_phone': '(646) 861-2152',
  'distance': 416.518495799184,
  'id': 'shaking-crab-new-york-4',
  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LzYQURzDMzioeCFsGphyZw/o.jpg',
  'is_closed': False,
  'location': {'address1': '2869 Broadway',
   'address2': '',
   'address3': None,
   'city': 'New York',
   'country': 'US',
   'display_address': ['2869 Broadway', 'New York, NY 10025'],
   'state': 'NY',
   'zip_code': '10025'},
  'name': 'Shaking Crab',
  'phone': '+16468612152',
  'price': '$$',
  'rating': 4.0,
  'review_count': 117,
  'transactions': [],
  'url': 'https://www.yelp.com/biz/shaking-crab-new-york-4?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'seafood', 'title': 'Seafood'},
   {'alias': 'sandwiches', 'title': 'Sandwiches'},
   {'alias': 'bars', 'title': 'Bars'}],
  'coordinates': {'latitude': 40.80486, 'longitude': -73.95567},
  'display_phone': '(646) 649-3356',
  'distance': 650.95495769709,
  'id': 'lolos-seafood-shack-new-york',
  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KPT7UUYDhCSfs1E8NUfeKw/o.jpg',
  'is_closed': False,
  'location': {'address1': '303 W 116th St',
   'address2': '',
   'address3': '',
   'city': 'New York',
   'country': 'US',
   'display_address': ['303 W 116th St', 'New York, NY 10026'],
   'state': 'NY',
   'zip_code': '10026'},
  'name': "Lolo's Seafood Shack",
  'phone': '+16466493356',
  'price': '$$',
  'rating': 4.0,
  'review_count': 445,
  'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
  'url': 'https://www.yelp.com/biz/lolos-seafood-shack-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
  'coordinates': {'latitude': 40.79898, 'longitude': -73.962707},
  'display_phone': '(212) 866-8886',
  'distance': 955.9464768322559,
  'id': 'saiguette-new-york',
  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CGSy1Ni2iaxYuTq3QuWEgg/o.jpg',
  'is_closed': False,
  'location': {'address1': '935 Columbus Ave',
   'address2': '',
   'address3': '',
   'city': 'New York',
   'country': 'US',
   'display_address': ['935 Columbus Ave', 'New York, NY 10025'],
   'state': 'NY',
   'zip_code': '10025'},
  'name': 'Saiguette',
  'phone': '+12128668886',
  'price': '$$',
  'rating': 4.0,
  'review_count': 439,
  'transactions': [],
  'url': 'https://www.yelp.com/biz/saiguette-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'thai', 'title': 'Thai'},
   {'alias': 'noodles', 'title': 'Noodles'},
   {'alias': 'soup', 'title': 'Soup'}],
  'coordinates': {'latitude': 40.80132, 'longitude': -73.96529},
  'display_phone': '(212) 280-4575',
  'distance': 730.152116177724,
  'id': 'thai-market-new-york',
  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-EJySfBhCM-e1VcgA2QHBA/o.jpg',
  'is_closed': False,
  'location': {'address1': '960 Amsterdam Ave',
   'address2': '',
   'address3': '',
   'city': 'New York',
   'country': 'US',
   'display_address': ['960 Amsterdam Ave', 'New York, NY 10025'],
   'state': 'NY',
   'zip_code': '10025'},
  'name': 'Thai Market',
  'phone': '+12122804575',
  'price': '$$',
  'rating': 4.0,
  'review_count': 804,
  'transactions': [],
  'url': 'https://www.yelp.com/biz/thai-market-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'seafood', 'title': 'Seafood'},
   {'alias': 'wine_bars', 'title': 'Wine Bars'},
   {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
  'coordinates': {'latitude': 40.80613, 'longitude': -73.95317},
  'display_phone': '(212) 280-2248',
  'distance': 793.971716976124,
  'id': 'b2-harlem-new-york',
  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q-I6upyPkIXYyWa-k2JOFw/o.jpg',
  'is_closed': False,
  'location': {'address1': '271 W 119th St',
   'address2': '',
   'address3': None,
   'city': 'New York',
   'country': 'US',
   'display_address': ['271 W 119th St', 'New York, NY 10026'],
   'state': 'NY',
   'zip_code': '10026'},
  'name': 'B2 Harlem',
  'phone': '+12122802248',
  'price': '$$',
  'rating': 4.0,
  'review_count': 110,
  'transactions': ['restaurant_reservation'],
  'url': 'https://www.yelp.com/biz/b2-harlem-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'southern', 'title': 'Southern'},
   {'alias': 'soulfood', 'title': 'Soul Food'}],
  'coordinates': {'latitude': 40.802466318157, 'longitude': -73.950421812439},
  'display_phone': '(212) 280-8779',
  'distance': 1166.929571627876,
  'id': 'amy-ruths-new-york',
  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SF0i1bIPhyOr0NPUx17tzQ/o.jpg',
  'is_closed': False,
  'location': {'address1': '113 W 116th St',
   'address2': '',
   'address3': '',
   'city': 'New York',
   'country': 'US',
   'display_address': ['113 W 116th St', 'New York, NY 10026'],
   'state': 'NY',
   'zip_code': '10026'},
  'name': "Amy Ruth's",
  'phone': '+12122808779',
  'price': '$$',
  'rating': 4.0,
  'review_count': 1975,
  'transactions': [],
  'url': 'https://www.yelp.com/biz/amy-ruths-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'italian', 'title': 'Italian'}],
  'coordinates': {'latitude': 40.7988462, 'longitude': -73.967065},
  'display_phone': '(212) 665-0033',
  'distance': 1060.243640318082,
  'id': 'arco-cafe-new-york',
  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WMC-GLfLlBaOWcaJhahQLQ/o.jpg',
  'is_closed': False,
  'location': {'address1': '886 Amsterdam Ave',
   'address2': None,
   'address3': '',
   'city': 'New York',
   'country': 'US',
   'display_address': ['886 Amsterdam Ave', 'New York, NY 10025'],
   'state': 'NY',
   'zip_code': '10025'},
  'name': 'Arco Cafe',
  'phone': '+12126650033',
  'price': '$$',
  'rating': 4.5,
  'review_count': 196,
  'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
  'url': 'https://www.yelp.com/biz/arco-cafe-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
  'coordinates': {'latitude': 40.8055649, 'longitude': -73.9653549},
  'display_phone': '(212) 776-4047',
  'distance': 329.396599380176,
  'id': 'dig-inn-new-york-14',
  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GUm5PEKC2lfQR9PaoOZz7Q/o.jpg',
  'is_closed': False,
  'location': {'address1': '2884 Broadway',
   'address2': None,
   'address3': '',
   'city': 'New York',
   'country': 'US',
   'display_address': ['2884 Broadway', 'New York, NY 10025'],
   'state': 'NY',
   'zip_code': '10025'},
  'name': 'Dig Inn',
  'phone': '+12127764047',
  'price': '$$',
  'rating': 4.0,
  'review_count': 216,
  'transactions': [],
  'url': 'https://www.yelp.com/biz/dig-inn-new-york-14?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
   {'alias': 'soulfood', 'title': 'Soul Food'}],
  'coordinates': {'latitude': 40.80095, 'longitude': -73.96141},
  'display_phone': '(646) 438-9832',
  'distance': 748.031956158958,
  'id': 'fredas-caribbean-and-soul-cuisine-new-york',
  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4JLFuFJ2kpnpMHO7ZSqvyQ/o.jpg',
  'is_closed': False,
  'location': {'address1': '993 Columbus Ave',
   'address2': '',
   'address3': '',
   'city': 'New York',
   'country': 'US',
   'display_address': ['993 Columbus Ave', 'New York, NY 10025'],
   'state': 'NY',
   'zip_code': '10025'},
  'name': "Freda's Caribbean & Soul Cuisine",
  'phone': '+16464389832',
  'price': '$$',
  'rating': 4.0,
  'review_count': 412,
  'transactions': ['delivery', 'pickup'],
  'url': 'https://www.yelp.com/biz/fredas-caribbean-and-soul-cuisine-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
   {'alias': 'bars', 'title': 'Bars'}],
  'coordinates': {'latitude': 40.8094002234406,
   'longitude': -73.9536950700793},
  'display_phone': '(212) 729-1850',
  'distance': 771.420259576252,
  'id': 'clay-new-york-3',
  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GCqqQR3HpapriwWMyFXzVw/o.jpg',
  'is_closed': False,
  'location': {'address1': '553 Manhattan Ave',
   'address2': '',
   'address3': None,
   'city': 'New York',
   'country': 'US',
   'display_address': ['553 Manhattan Ave', 'New York, NY 10027'],
   'state': 'NY',
   'zip_code': '10027'},
  'name': 'Clay',
  'phone': '+12127291850',
  'price': '$$$',
  'rating': 4.5,
  'review_count': 54,
  'transactions': [],
  'url': 'https://www.yelp.com/biz/clay-new-york-3?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
  'coordinates': {'latitude': 40.7952, 'longitude': -73.96992},
  'display_phone': '(917) 265-8173',
  'distance': 1509.007638081238,
  'id': 'guacamole-mexican-restaurant-new-york',
  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IhGd10oecyGbd1MT3Wmv-A/o.jpg',
  'is_closed': False,
  'location': {'address1': '768 Amsterdam Ave',
   'address2': '',
   'address3': None,
   'city': 'New York',
   'country': 'US',
   'display_address': ['768 Amsterdam Ave', 'New York, NY 10025'],
   'state': 'NY',
   'zip_code': '10025'},
  'name': 'Guacamole Mexican Restaurant',
  'phone': '+19172658173',
  'price': '$$',
  'rating': 4.5,
  'review_count': 18,
  'transactions': [],
  'url': 'https://www.yelp.com/biz/guacamole-mexican-restaurant-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
   {'alias': 'chinese', 'title': 'Chinese'}],
  'coordinates': {'latitude': 40.81403, 'longitude': -73.95983},
  'display_phone': '(212) 961-0300',
  'distance': 755.8075477081619,
  'id': 'la-salle-dumpling-room-new-york',
  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fYtNliCFcREcQ0AkcykBqw/o.jpg',
  'is_closed': False,
  'location': {'address1': '3141 Broadway',
   'address2': None,
   'address3': '',
   'city': 'New York',
   'country': 'US',
   'display_address': ['3141 Broadway', 'New York, NY 10027'],
   'state': 'NY',
   'zip_code': '10027'},
  'name': 'La Salle Dumpling Room',
  'phone': '+12129610300',
  'price': '$$',
  'rating': 4.0,
  'review_count': 120,
  'transactions': [],
  'url': 'https://www.yelp.com/biz/la-salle-dumpling-room-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
 {'categories': [{'alias': 'bars', 'title': 'Bars'},
   {'alias': 'newmexican', 'title': 'New Mexican Cuisine'},
   {'alias': 'tapas', 'title': 'Tapas Bars'}],
  'coordinates': {'latitude': 40.8061, 'longitude': -73.95302},
  'display_phone': '(212) 418-1220',
  'distance': 814.813837230426,
  'id': 'la-diagonal-new-york-5',
  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dKjkwzoQEi5m5Mb7TKbvyg/o.jpg',
  'is_closed': False,
  'location': {'address1': '185 St Nicholas Ave',
   'address2': None,
   'address3': None,
   'city': 'New York',
   'country': 'US',
   'display_address': ['185 St Nicholas Ave', 'New York, NY 10026'],
   'state': 'NY',
   'zip_code': '10026'},
  'name': 'La Diagonal',
  'phone': '+12124181220',
  'price': '$$',
  'rating': 4.0,
  'review_count': 82,
  'transactions': ['restaurant_reservation'],
  'url': 'https://www.yelp.com/biz/la-diagonal-new-york-5?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'}]

# %%
content.[get(address)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-c5bd73177620> in <module>()
# ----> 1 content.get(address)
#
# AttributeError: 'list' object has no attribute 'get'
